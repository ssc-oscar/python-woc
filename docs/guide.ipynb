# %% [markdown]
# ### Task 1: Install the python package

# %%
# !python3 -m pip install -U python-woc
# Out:
# Requirement already satisfied: python-woc in /export/data/play/rzhe/miniforge3/lib/python3.10/site-packages (0.2.2)
# Requirement already satisfied: chardet<6.0.0,>=5.2.0 in /export/data/play/rzhe/miniforge3/lib/python3.10/site-packages (from python-woc) (5.2.0)
# Requirement already satisfied: python-lzf<0.3.0,>=0.2.4 in /export/data/play/rzhe/miniforge3/lib/python3.10/site-packages (from python-woc) (0.2.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.65.0 in /export/data/play/rzhe/miniforge3/lib/python3.10/site-packages (from python-woc) (4.66.4)
# WARNING: Error parsing requirements for certifi: [Errno 2] No such file or directory: '/export/data/play/rzhe/miniforge3/lib/python3.10/site-packages/certifi-2023.11.17.dist-info/METADATA'

# %% [markdown]
# ### Task 2: Basic operations

# %%
from woc.local import WocMapsLocal
from woc.objects import *

woc = WocMapsLocal()
init_woc_objects(woc)

# or with a specific version
# woc = WocMapsLocal(version='V')

# %%
# print the name and version of all maps

from pprint import pprint

pprint([(m.name, m.version) for m in woc.maps])
# Out:
# [('c2fbb', 'V'),
#  ('obb2cf', 'V'),
#  ('bb2cf', 'V'),
#  ('a2f', 'V'),
#  ('a2f', 'T'),
#  ('b2A', 'U'),
#  ('b2a', 'U'),
#  ('A2f', 'V'),
#  ('P2a', 'V'),
#  ('b2P', 'V'),
#  ('b2f', 'V'),
#  ('a2P', 'V'),
#  ('a2P', 'T'),
#  ('b2fa', 'V'),
#  ('b2tac', 'V'),
#  ('c2p', 'V3'),
#  ('c2p', 'V'),
#  ('c2pc', 'U'),
#  ('c2cc', 'V'),
#  ('c2rhp', 'U'),
#  ('p2a', 'V'),
#  ('ob2b', 'U'),
#  ('A2a', 'V'),
#  ('A2a', 'U'),
#  ('A2a', 'T'),
#  ('A2a', 'S'),
#  ('a2A', 'V'),
#  ('a2A', 'T'),
#  ('a2A', 'S'),
#  ('c2dat', 'V'),
#  ('c2dat', 'U'),
#  ('a2c', 'V'),
#  ('a2fb', 'T'),
#  ('a2fb', 'S'),
#  ('P2c', 'V'),
#  ('P2c', 'U'),
#  ('c2r', 'T'),
#  ('c2r', 'S'),
#  ('P2p', 'V'),
#  ('P2p', 'U'),
#  ('P2p', 'T'),
#  ('P2p', 'S'),
#  ('P2p', 'R'),
#  ('c2h', 'T'),
#  ('c2h', 'S'),
#  ('c2P', 'V'),
#  ('c2P', 'U'),
#  ('p2P', 'V'),
#  ('p2P', 'U'),
#  ('p2P', 'T'),
#  ('p2P', 'S'),
#  ('p2P', 'R'),
#  ('A2c', 'V'),
#  ('A2c', 'U'),
#  ('A2P', 'V'),
#  ('A2P', 'U'),
#  ('P2A', 'V'),
#  ('P2A', 'U'),
#  ('a2p', 'V'),
#  ('a2p', 'U'),
#  ('a2p', 'T'),
#  ('A2b', 'V'),
#  ('A2b', 'U'),
#  ('A2fb', 'V'),
#  ('P2b', 'V'),
#  ('b2BadDate', 'T'),
#  ('b2ManyP', 'T'),
#  ('f2b', 'T'),
#  ('f2b', 'S'),
#  ('b2ob', 'U'),
#  ('P2f', 'T'),
#  ('a2Aw100', 'S'),
#  ('f2a', 'T'),
#  ('A2aw100', 'S'),
#  ('f2c', 'T'),
#  ('f2c', 'S'),
#  ('b2c', 'T'),
#  ('P2fb', 'V'),
#  ('c2b', 'V'),
#  ('t2c', 'S'),
#  ('c2f', 'S'),
#  ('c2ta', 'S'),
#  ('c2td', 'S'),
#  ('c2td', 'R'),
#  ('b2tk', 'S'),
#  ('b2tk', 'R'),
#  ('td2f', 'S'),
#  ('td2f', 'R'),
#  ('td2c', 'S'),
#  ('td2c', 'R'),
#  ('p2c', 'V')]

# %% [markdown]
# ### Task 3: Determine the author of the parent commit for commit 009d7b6da9c4419fe96ffd1fffb2ee61fa61532a

# %%
# 1. get_values API

woc.get_values('c2ta', 
               woc.get_values('c2pc', '009d7b6da9c4419fe96ffd1fffb2ee61fa61532a')[0])
# Out:
# ['1092637858', 'Maxim Konovalov <maxim@FreeBSD.org>']

# %%
# 2. show_content API

woc.show_content('commit', '009d7b6da9c4419fe96ffd1fffb2ee61fa61532a')
# Out:
# ('464ac950171f673d1e45e2134ac9a52eca422132',
#  ('dddff9a89ddd7098a1625cafd3c9d1aa87474cc7',),
#  ('Warner Losh <imp@FreeBSD.org>', '1092638038', '+0000'),
#  ('Warner Losh <imp@FreeBSD.org>', '1092638038', '+0000'),
#  "Don't need to declare cbb module.  don't know why I never saw\nduplicate messages..\n")

# %%
# 3. objects API

Commit('009d7b6da9c4419fe96ffd1fffb2ee61fa61532a').parents[0].author
# Out:
# Author(Maxim Konovalov <maxim@FreeBSD.org>)

# %% [markdown]
# ### Task 4: Find out who and when first commited "Hello World"

# %%
from hashlib import sha1

def git_hash_object(data, type_='blob'):
    """Compute the Git object ID for a given type and data.
    """
    s = f'{type_} {len(data)}\0'.encode() + data
    return sha1(s).hexdigest()

git_hash_object(b'Hello, World!\n')
# Out:
# '8ab686eafeb1f44702738c8b0f24f2567c36da6d'

# %%
# 1. get_values API

t, a, c = woc.get_values('b2fa', git_hash_object(b'Hello, World!\n'))
print('Time:', datetime.fromtimestamp(int(t)))
print('Author:', a)
print('Project:', woc.get_values('c2p', c)[0])
# Out:
# Time: 1999-12-31 19:25:29
# Author: Roberto Cadena Vega <robblack00_7@hotmail.com
# Project: robblack007_scripts-beagleboard

# %%
# 2. objects API

t, a, c = Blob('8ab686eafeb1f44702738c8b0f24f2567c36da6d').first_author
print('Time:', t)
print('Author:', a)
print('Project:', c.projects[0].url)
# Out:
# Time: 1999-12-31 19:25:29
# Author: Roberto Cadena Vega <robblack00_7@hotmail.com
# Project: https://github.com/robblack007/scripts-beagleboard

# %% [markdown]
# ### Task 5: Find the aliases of the author

# %%
# 1. get_values API

woc.get_values('A2a', woc.get_values('a2A', 'Roberto Cadena Vega <robblack00_7@hotmail.com>')[0])
# Out:
# ['Roberto Cadena Vega <robblack00_7@hotmail.com>',
#  'robblack007 <robblack00_7@hotmail.com>']

# %%
# 2. objects API

Author('Roberto Cadena Vega <robblack00_7@hotmail.com>').aliases
# Out:
# [Author(Roberto Cadena Vega <robblack00_7@hotmail.com>),
#  Author(robblack007 <robblack00_7@hotmail.com>)]

# %% [markdown]
# ### Task 6: List the files in 'team-combinatorics_shuwashuwa-server' and save them to a directory

# %%
list(Project('team-combinatorics_shuwashuwa-server').head.tree.traverse())
# Out:
# [(File(.github/workflows/build-test.yml),
#   Blob(00a33c83a095ff8b4e0a48864234d6c04fbefb69)),
#  (File(.github/workflows/upload-artifact.yml),
#   Blob(867dec12e7466a31ad3bfdbb67a00b6d6383ae0c)),
#  (File(.gitignore), Blob(91cea399a919aaca5bd1c1be0d8a9f309095f875)),
#  (File(LICENSE), Blob(f288702d2fa16d3cdf0035b15a9fcbc552cd88e7)),
#  (File(README.md), Blob(b98c3d928866e6558793d2aacbca4037480fea5e)),
#  (File(doc/Java开发手册（嵩山版）.pdf), Blob(4d4c5cc9a1a3d42b92c3fc169f5215a2e60ad86f)),
#  (File(doc/docker.md), Blob(cf4dcb8b40210fbef88d483d26bae16c176bd1d3)),
#  (File(doc/github-actions.md), Blob(6b30f9626e9d34750e2b6faf1fada2bd90d1b79d)),
#  (File(doc/todo.md), Blob(e54518e2043803c59bcec43a1ed8cba145b7c0ef)),
#  (File(doc/webhook.md), Blob(f83a89dd5efcf76017804e793cf7712e0844257e)),
#  (File(helpful_tools/database/csv/activity_info.csv),
#   Blob(081b5902a8b6fe393c700ebaa0bfe265ccea4dea)),
#  (File(helpful_tools/database/csv/activity_time_slot.csv),
#   Blob(90d5c2ecac32368d62ea76d65f466a5f1f50eaef)),
#  (File(helpful_tools/database/csv/admin.csv),
#   Blob(d2a3219930624b3a40214b191d2c96e63cbc9463)),
#  (File(helpful_tools/database/csv/cache_pic.csv),
#   Blob(9ecad6833cba2ce8df637298732ebec8bbe95126)),
#  (File(helpful_tools/database/csv/service_event.csv),
#   Blob(e453f5ac5fc80f8fe8f52942dbd57bbee3fe3ff6)),
#  (File(helpful_tools/database/csv/service_form.csv),
#   Blob(2d14bf0ca6c6693aeffb86e2156425c3ca21d5c3)),
#  (File(helpful_tools/database/csv/service_pic.csv),
#   Blob(eeea92da4463adbf9d95d7f086ad56a297e3c6d9)),
#  (File(helpful_tools/database/csv/user.csv),
#   Blob(7f02aad0b859b856b718d93a9e948d2e3f87ed59)),
#  (File(helpful_tools/database/csv/volunteer.csv),
#   Blob(fbb2c078a3bafaf6da5764f59533eb5881150843)),
#  (File(helpful_tools/database/csv/volunteer_application.csv),
#   Blob(a7247e0efbc7a3ec90e60c8dc14dd0019a3ba9c4)),
#  (File(helpful_tools/database/relationship/user_service_form.csv),
#   Blob(e843d1e4b26171ffa2364cdbad6afc43eb16567e)),
#  (File(helpful_tools/database/relationship/user_volunteer_application.csv),
#   Blob(59dba82b31b98e9537a84dbfae89df5448a027e3)),
#  (File(helpful_tools/database/utils/auto_generate.py),
#   Blob(2a0496df1b053b0949f45ff9b3033b409a00b210)),
#  (File(helpful_tools/database/utils/generate_result_map.py),
#   Blob(ae30c45e5269e678d7680af4eb997df7044f9a06)),
#  (File(helpful_tools/database/utils/utils.py),
#   Blob(06a7b6a0ea6788f1f537229ec62171c7c6737f7f)),
#  (File(helpful_tools/init_data/csv/user_init.csv),
#   Blob(8b137891791fe96927ad78e64b0aad7bded08bdc)),
#  (File(helpful_tools/init_data/ref_csv/user.csv),
#   Blob(373d14de1d42155621a8a0a27e116edc8a54818c)),
#  (File(helpful_tools/init_data/utils/generate_data.py),
#   Blob(ae0647dbbce892e9ec4afe6d86f11054b6dcb4c2)),
#  (File(pom.xml), Blob(b4a554dcd189d6605bbd5c0f53adf3121fe27cca)),
#  (File(server-dev/.env), Blob(9cfa606967897fbe2c8eac25dd68b164e8d7aa9a)),
#  (File(server-dev/docker-compose.yml),
#   Blob(c8d6af8e0f237eb5ea8270fd31b00a0b5b9f9e0c)),
#  (File(server-dev/entrypoint.sh),
#   Blob(5df3bd03fd108ecc75c7ff1e7b24897b35a4f858)),
#  (File(server-dev/run-dev.sh), Blob(c29be2a7ca37ea8fcc0f89691309917b3a152059)),
#  (File(server-dev/settings.xml),
#   Blob(8254140adf9b2c2462ff966895db5d1ac1b19a9f)),
#  (File(server-dev/shuwashuwa-server.dockerfile),
#   Blob(8d1d72e55780ba47843bbd4dd81527c68a409b63)),
#  (File(server-dev/wait-for-it.sh),
#   Blob(d990e0d364f576ee83cd699707076ca49ad36a4d)),
#  (File(server-production/.env),
#   Blob(ed85e91a9766053840b2ca3a2869e33bbd06c194)),
#  (File(server-production/docker-compose.yml),
#   Blob(47c4b07e24d6101b38bd7b08e6ef7451c4cb745d)),
#  (File(server-production/docker-log.txt),
#   Blob(975b9e13d25181b7863d025d33f928c87c310a27)),
#  (File(server-production/entrypoint.sh),
#   Blob(f7a13d3f0463abbdc6855c1c54997324b9580bc4)),
#  (File(server-production/run-production.sh),
#   Blob(a6f8be4464c5fa481a48d25de52500fea0e2e3c5)),
#  (File(server-production/shuwashuwa-server.caddyfile),
#   Blob(cbcb46cc7d1f7342f9f55b65822d62deb17d9ccf)),
#  (File(server-production/shuwashuwa-server.dockerfile),
#   Blob(1b98588075fe018012921d6b152d7b82fd3afd95)),
#  (File(server-production/wait-for-it.sh),
#   Blob(d990e0d364f576ee83cd699707076ca49ad36a4d)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/MainApplication.java),
#   Blob(f9ca05667a93c409c8d4869d9356f8bcd9160d22)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/annotation/AdminAccess.java),
#   Blob(0595cdf09a9c904f93eedbfbf735653694c41b14)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/annotation/AllAccess.java),
#   Blob(842511621165fc2b2fd5cb03d204f02f1f985c31)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/annotation/NoToken.java),
#   Blob(b4ae11e3b954f9b5adcd8948bdfb14c421f7e2ea)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/annotation/SUAccess.java),
#   Blob(6f1184641b4cb26a37350fbae53ad530f0fea8b0)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/annotation/VolunteerAccess.java),
#   Blob(d395c2c3e503f328de7a4964ff0f6b6b63f2d8f8)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/config/DataSourceConfiguration.java),
#   Blob(0cf146479d069bf0f657e5d611b17fc9b2d2586a)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/config/RestTemplateConfig.java),
#   Blob(caddbf84c56b1db7ced2bd665f5e87b38584abb9)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/config/ShuwashuwaWebMvcConfig.java),
#   Blob(9e93d0abf5b7554860c2d82eb3baeaa02ed2c193)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/config/SwaggerConfig.java),
#   Blob(c8f906404a71f7ba138b54a8cb03b7b8b937a727)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/controller/ActivityController.java),
#   Blob(d78ebca78e92a5680adb382c2939f70a2be1552b)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/controller/EventController.java),
#   Blob(3f78814edbc863ec24d4efdd36437186a66366ae)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/controller/ImageController.java),
#   Blob(beb53984333b5ec2f837e391e947382b54f39b8e)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/controller/SuperAdministratorController.java),
#   Blob(243b4f449c25b7c985d4ba8f6fb7d2a48e302c98)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/controller/TestController.java),
#   Blob(37d5db7c087f31a56d625bb2fceebd4c99d904bd)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/controller/UserController.java),
#   Blob(cb990730c1987f2af2fc1463aa750937f606ba88)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/controller/VolunteerController.java),
#   Blob(7b95c3635d7f9f591331e0decc9970c384ef9b18)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/dao/ActivityInfoDao.java),
#   Blob(1107d486c7d85fa888b309b673ef181975e991e8)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/dao/ActivityTimeSlotDao.java),
#   Blob(b4fe5c0fc77ea0fc25074ffe6f967e53ee294ba7)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/dao/AdminDao.java),
#   Blob(0a0de88c17dffc07b768fd70891063df0891fe55)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/dao/CachePicDao.java),
#   Blob(00bc58014e8938dae35cca2bd1685a3081f1a132)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/dao/MethodsOfTesting.java),
#   Blob(f6afdb958853c9f766997854f6580a05e0f48ecf)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/dao/ServiceEventDao.java),
#   Blob(4973a05515a1ca47bb64795a71c23c0b24725069)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/dao/ServiceFormDao.java),
#   Blob(51d7f31d29cab62f26feccb196e80b6e3efeb253)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/dao/ServicePicDao.java),
#   Blob(c4dce762a8da3502bc3bb8384869c08705f09d60)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/dao/UserDao.java),
#   Blob(2937387cbd241201f9d15dc78807a7891bf75275)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/dao/VolunteerApplicationDao.java),
#   Blob(00e7ad77958f70a9bbfe0767d36f568272bbd8d1)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/dao/VolunteerDao.java),
#   Blob(4179ea3e8f92da01e49982ecc2d4233aaccc686d)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/dao/co/CachePicCO.java),
#   Blob(1102a338168113c9a287e09efaaab19ec327ef86)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/dao/co/SelectActivityCO.java),
#   Blob(b91042d8bad871c09d10a7d3c7835712d5421b75)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/dao/co/SelectApplicationCO.java),
#   Blob(d5c75bd7d67795153a46028de11fec1b3688565e)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/dao/co/SelectServiceEventCO.java),
#   Blob(71d154226f3d10e363f3860ab76e131a66e29e56)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/exception/ErrorInfoEnum.java),
#   Blob(d533cd2e82782aef578facc598b2d7740ab0b5b8)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/exception/GlobalExceptionHandler.java),
#   Blob(8856191680d59944b078dd1bb6ce4bf716da7a05)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/exception/KnownException.java),
#   Blob(473cfb7777b5ecd8c941448d3041aa164841b90f)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/interceptor/AuthorizationInterceptor.java),
#   Blob(ea4c6e34946b4594e86f766d31bfaba8869e8b04)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/bo/ActivityTimeSlotBO.java),
#   Blob(0c2fceab99df105c19ff86562727358de90e423a)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/bo/ServiceAbstractBO.java),
#   Blob(704ed07f5af7c743286d434010a060adb86fc644)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/bo/ServiceEventDetailBO.java),
#   Blob(ac5cc0c9a8b3934f1296aac81db3a5a7fa4e11a5)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/bo/VolunteerApplicationAbstractBO.java),
#   Blob(ab40b121c5cf7176f267100571eb129dc7e49a7c)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/bo/VolunteerApplicationDetailBO.java),
#   Blob(a6c4b657725d80c055b59d57bb4d338765ed4b11)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/dto/ActivityLaunchDTO.java),
#   Blob(6d1bfbffd3e03a37709e93c5794053ca00053f3b)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/dto/ActivityResponseDTO.java),
#   Blob(20b3050904abc83c742275ad016ee5b5d2bdc390)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/dto/ActivityTimeSlotDTO.java),
#   Blob(8778f72a5f767ce8b4f7fd746482c1c4beeaf757)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/dto/ActivityUpdateDTO.java),
#   Blob(316edcf524f0f2896c665f2921cfbf9242236f1e)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/dto/AdminDTO.java),
#   Blob(781d8d159e51f103005242839e7faeff031eafb7)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/dto/CommonResult.java),
#   Blob(a9692ae498a075a8d0d9e68b87c433241457da1f)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/dto/LogInInfoDTO.java),
#   Blob(2529b6ce2a0b18e9d0bdadd8be4c039d6867d19d)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/dto/LogInSuccessDTO.java),
#   Blob(63b06dfd5b414bda926de93dd99e318880c1c55a)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/dto/NoticeMessage.java),
#   Blob(3fcabffc94d79cdd57be86bc6723d57938aab337)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/dto/ServiceAbstractDTO.java),
#   Blob(3411ef2933dae0479483d21063091f276aba51df)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/dto/ServiceEventAuditDTO.java),
#   Blob(12a9a1fdea841edb112eabbf8eee9fa47ccc29d2)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/dto/ServiceEventDetailDTO.java),
#   Blob(b817e3525db91a0fadb8fcd0300347e812fef2cb)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/dto/ServiceFormDTO.java),
#   Blob(ee1f2ee39d15d5776fba4a6156c1f70f2b05d31d)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/dto/ServiceFormSubmitDTO.java),
#   Blob(fcfe203e7e0ab25159cdfb1ebcab0e13286e4702)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/dto/ServiceSimpleUpdateDTO.java),
#   Blob(de291dfaa942d621f85de012ffed82435459582a)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/dto/UserInfoResponseDTO.java),
#   Blob(eefcc9adb33eca0c6ad1e9d2d6ff5c09c090a387)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/dto/UserInfoUpdateDTO.java),
#   Blob(a93f7b54a3b07e22b1015491a815c0c75c35b2df)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/dto/VolunteerApplicationAbstractDTO.java),
#   Blob(ba25cdef1032361f10488b0ad9e089d9eb7d7763)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/dto/VolunteerApplicationAdditionDTO.java),
#   Blob(d3223524e455555e202efc82e74783935bf0d544)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/dto/VolunteerApplicationAuditDTO.java),
#   Blob(6f310d64c83b92c4602aa82097bbcc4527e1fa82)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/dto/VolunteerApplicationDetailDTO.java),
#   Blob(9f490019ed04d12bde3e400b0320650d6a9196e4)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/dto/VolunteerDTO.java),
#   Blob(c7c28188accee2375c0790cc018c035ef23df9fd)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/dto/WechatAppCodeDTO.java),
#   Blob(63e5d83bcdb726c66a02014192d60f2e126082e1)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/dto/WechatNoticeDTO.java),
#   Blob(694b98d67c3c51bb08f2dc4783dab6ad3fad3e88)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/po/ActivityInfoPO.java),
#   Blob(2a223b3781b6f46496620fcff57020b97131b93b)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/po/ActivityTimeSlotPO.java),
#   Blob(4c275b047542398c42aa5f631310ca21eb0d8393)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/po/AdminPO.java),
#   Blob(9ccb81ddac274ace04bd186d4e5f18078ce00a2c)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/po/CachePicPO.java),
#   Blob(cce993718fb91a52adea9d816d8437d475ac14e3)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/po/ServiceEventPO.java),
#   Blob(5171f8e49f6513475690f86a31638b28bca4d459)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/po/ServiceFormPO.java),
#   Blob(f2e917c722feb1d64c4e5cb52e6a5e173e896cc7)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/po/ServicePicPO.java),
#   Blob(d2f62551c2d50a0a8cdcb4fa017b0483a5e33da3)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/po/UserPO.java),
#   Blob(62fa741a673661662f5e6718eeefa3f9d322147e)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/po/VolunteerApplicationPO.java),
#   Blob(7a1df769d8f083c99b30bf560f4fb115bb9bcefb)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/model/po/VolunteerPO.java),
#   Blob(5f9e4788a08c7515ba3594e10201f97b2a0cba20)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/service/ActivityService.java),
#   Blob(ea05c70a7fbe6262dbf44d16ce79b9e76e0d0e71)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/service/EventService.java),
#   Blob(0c644bde151e76e6a3701aafb33094346180fb61)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/service/ImageStorageService.java),
#   Blob(5f1ff0d12ddad9a11b36d595fea1aa2a7971d022)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/service/SuperAdministratorService.java),
#   Blob(12dc2f03d4fa25133d17bfb62b6d79d4fb211a7c)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/service/UserService.java),
#   Blob(a1bc506d1bbdb814ea7ae2bc51c770f198a42caa)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/service/VolunteerService.java),
#   Blob(27020e0248c95d1e5d0146b87428117d000befea)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/service/impl/ActivityServiceImpl.java),
#   Blob(81f8eed832ecbb25d0303b7d5448263df76afdd5)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/service/impl/EventServiceImpl.java),
#   Blob(5f101f2784a8c3705d40e5d4788f4c007ac093fb)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/service/impl/ImageStorageServiceImpl.java),
#   Blob(4bbec57fb7e3d124d79fa25a1cb40cafef25cf64)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/service/impl/SuperAdministratorServiceImpl.java),
#   Blob(d98e02e1f4b2e82c6829a1ec6703c92a569d08e5)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/service/impl/UserServiceImpl.java),
#   Blob(aa1743881ecf9a0a6db8001be1d632cf364cf977)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/service/impl/VolunteerServiceImpl.java),
#   Blob(b90e335b95be9a7ab45933cd0e3d119a86bca8d2)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/utils/DTOUtil.java),
#   Blob(7e6f6855dd714e7f98a2279b106400c631cee8c5)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/utils/MD5Util.java),
#   Blob(d3e8b383af61e72296ad0a906cc0137d603c2110)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/utils/PropertiesConstants.java),
#   Blob(f0aac96b8157ece90cf57a9689278ffbd4716183)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/utils/TokenUtil.java),
#   Blob(502b228cd24e772f7b634406e191337bf37e123f)),
#  (File(src/main/java/team/combinatorics/shuwashuwa/utils/WechatUtil.java),
#   Blob(1c7a7ae49f058c91a79eb5e37d32ca84539a010d)),
#  (File(src/main/resources/application.properties),
#   Blob(4dbc330ea710d99385316a474e4199e94c335174)),
#  (File(src/main/resources/config/generatorConfig.xml),
#   Blob(7e4eafb431583de7b1a15808f101747ac2f12491)),
#  (File(src/main/resources/mapper/ActivityInfoMapper.xml),
#   Blob(c434c4cc4f352e20e90a77fc2da23f578ca8eee7)),
#  (File(src/main/resources/mapper/ActivityTimeSlotMapper.xml),
#   Blob(ca145ccecd541faa93f9b8efbc4733978e04f828)),
#  (File(src/main/resources/mapper/AdminMapper.xml),
#   Blob(e6c06b6a243774800b45e2110e2850775a386783)),
#  (File(src/main/resources/mapper/CachePicMapper.xml),
#   Blob(768e77aa821629a73b2539cbc982c2c7e0532878)),
#  (File(src/main/resources/mapper/MethodsOfTestingMapper.xml),
#   Blob(7b87252491b78740cd17b7d180dfc10b27347e8e)),
#  (File(src/main/resources/mapper/ServiceEventMapper.xml),
#   Blob(ab4c0237e3863f8728cfb03f9ad1b8e17c55f9d2)),
#  (File(src/main/resources/mapper/ServiceFormMapper.xml),
#   Blob(3c5bef237a8bad31f40bf7bd790ae99fca0a41b6)),
#  (File(src/main/resources/mapper/ServicePicMapper.xml),
#   Blob(09d9deed3f4eca6b94b8a96a5eeff641dde7dcd2)),
#  (File(src/main/resources/mapper/UserMapper.xml),
#   Blob(d690d1de191d68e078c0f65beecaf102bdcfd215)),
#  (File(src/main/resources/mapper/VolunteerApplicationMapper.xml),
#   Blob(f30a5cd04a0130779ae5005bf54d6e3fcb6d9699)),
#  (File(src/main/resources/mapper/VolunteerMapper.xml),
#   Blob(6349accbc17e7e90f36532583173f736d11f5a04)),
#  (File(src/main/resources/shuwashuwa.properties),
#   Blob(0da04f7a4d5037c53915756e7f673f03be4deb8a)),
#  (File(src/main/resources/sql/init.sql),
#   Blob(47f16ad9ed591f9ab06245b319fbb8cf6b2b2ee3)),
#  (File(src/main/resources/static/test.txt),
#   Blob(d099fd693f463736696c4dcb669c48dc0bf49a27)),
#  (File(src/test/java/team/combinatorics/shuwashuwa/ShuwashuwaApplicationTests.java),
#   Blob(a02a858155480f2211f13fee4959b7998efabcb4)),
#  (File(src/test/java/team/combinatorics/shuwashuwa/dao/ActivityInfoDaoTest.java),
#   Blob(7fd10133be120e0aabeea980678b6cf115b8d5a4)),
#  (File(src/test/java/team/combinatorics/shuwashuwa/dao/ActivityTimeSlotDaoTest.java),
#   Blob(4156ba6fe40dd02adcecb28664fa62d89b87228c)),
#  (File(src/test/java/team/combinatorics/shuwashuwa/dao/AdminDaoTest.java),
#   Blob(ba41ee2bf21a99cb1064c40ab6bc08aa0d2178ce)),
#  (File(src/test/java/team/combinatorics/shuwashuwa/dao/CachePicDaoTest.java),
#   Blob(a436209f32c4138ec631235cb89b13bfa3c1f8b7)),
#  (File(src/test/java/team/combinatorics/shuwashuwa/dao/ServiceEventDaoTest.java),
#   Blob(37019a5cdab533b6c7be6573e9f254cfe0f394f5)),
#  (File(src/test/java/team/combinatorics/shuwashuwa/dao/ServiceFormDaoTest.java),
#   Blob(d7cf5d25036aee1650d0da544bfec8315ace9e36)),
#  (File(src/test/java/team/combinatorics/shuwashuwa/dao/ServicePicDaoTest.java),
#   Blob(bda967c46b4fc5ec958983778e81c902e1277045)),
#  (File(src/test/java/team/combinatorics/shuwashuwa/dao/UserDaoTest.java),
#   Blob(f4fdb086996e5aafb7b4906aded66ebdd4114385)),
#  (File(src/test/java/team/combinatorics/shuwashuwa/dao/VolunteerApplicationDaoTest.java),
#   Blob(a31ab79f49a1f998309bcb5aba7a0d74b45f38cf)),
#  (File(src/test/java/team/combinatorics/shuwashuwa/dao/VolunteerDaoTest.java),
#   Blob(f3ec3a797548b7f0963311eb7b16d50e5cecb554)),
#  (File(src/test/java/team/combinatorics/shuwashuwa/service/EventServiceTest.java),
#   Blob(33be3383bf72c0dbdbcbee521b20bd161053b2e0)),
#  (File(src/test/java/team/combinatorics/shuwashuwa/service/ImageStorageServiceTest.java),
#   Blob(5d01275df465a1f1d8dc71a7b4f1ddca13aac9ea)),
#  (File(src/test/java/team/combinatorics/shuwashuwa/service/SuperAdministratorServiceTest.java),
#   Blob(f26f932496a11ab60b26147bf06ba94e6eb2255d)),
#  (File(src/test/java/team/combinatorics/shuwashuwa/service/UserServiceTest.java),
#   Blob(1b3aa00286a88cec774816dff58cc1890379fe65)),
#  (File(src/test/java/team/combinatorics/shuwashuwa/utils/DTOUtilTest.java),
#   Blob(265fe91efd9aa56f22ceef270f446faf2ea96599)),
#  (File(src/test/java/team/combinatorics/shuwashuwa/utils/WechatUtilTest.java),
#   Blob(866c1593bf48fdb15eb3fc6a20114253bfdd139e)),
#  (File(src/test/resources/testImage.gif),
#   Blob(895a044b430de05934d0100a80aed27276e87694))]

# %%
Project('team-combinatorics_shuwashuwa-server')\
    .save('local_repo')
# Out:
# Failed to write blob 00a33c83a095ff8b4e0a48864234d6c04fbefb69: Invalid (offset, length) pair: [72919620]
# Failed to write blob 867dec12e7466a31ad3bfdbb67a00b6d6383ae0c: Invalid (offset, length) pair: [72937066]
# Failed to write blob 91cea399a919aaca5bd1c1be0d8a9f309095f875: Invalid (offset, length) pair: [72946090]
# Failed to write blob f288702d2fa16d3cdf0035b15a9fcbc552cd88e7: Invalid (offset, length) pair: [14176306]
# Failed to write blob b98c3d928866e6558793d2aacbca4037480fea5e: Invalid (offset, length) pair: [78355457]
# Failed to write blob cf4dcb8b40210fbef88d483d26bae16c176bd1d3: Invalid (offset, length) pair: [72935764]
# Failed to write blob 6b30f9626e9d34750e2b6faf1fada2bd90d1b79d: Invalid (offset, length) pair: [72930061]
# Failed to write blob e54518e2043803c59bcec43a1ed8cba145b7c0ef: Invalid (offset, length) pair: [72957996]
# Failed to write blob f83a89dd5efcf76017804e793cf7712e0844257e: Invalid (offset, length) pair: [75684111]
# Failed to write blob 081b5902a8b6fe393c700ebaa0bfe265ccea4dea: Invalid (offset, length) pair: [72943891]
# Failed to write blob 90d5c2ecac32368d62ea76d65f466a5f1f50eaef: Invalid (offset, length) pair: [72954059]
# Failed to write blob d2a3219930624b3a40214b191d2c96e63cbc9463: Invalid (offset, length) pair: [72935396]
# Failed to write blob 9ecad6833cba2ce8df637298732ebec8bbe95126: Invalid (offset, length) pair: [78352588]
# Failed to write blob e453f5ac5fc80f8fe8f52942dbd57bbee3fe3ff6: Invalid (offset, length) pair: [72949414]
# Failed to write blob 2d14bf0ca6c6693aeffb86e2156425c3ca21d5c3: Invalid (offset, length) pair: [78356903]
# Failed to write blob eeea92da4463adbf9d95d7f086ad56a297e3c6d9: Invalid (offset, length) pair: [72924957]
# Failed to write blob 7f02aad0b859b856b718d93a9e948d2e3f87ed59: Invalid (offset, length) pair: [75681740]
# Failed to write blob fbb2c078a3bafaf6da5764f59533eb5881150843: Invalid (offset, length) pair: [75658164]
# Failed to write blob a7247e0efbc7a3ec90e60c8dc14dd0019a3ba9c4: Invalid (offset, length) pair: [78349595]
# Failed to write blob e843d1e4b26171ffa2364cdbad6afc43eb16567e: Invalid (offset, length) pair: [72911754]
# Failed to write blob 59dba82b31b98e9537a84dbfae89df5448a027e3: Invalid (offset, length) pair: [72953160]
# Failed to write blob 2a0496df1b053b0949f45ff9b3033b409a00b210: Invalid (offset, length) pair: [78338651]
# Failed to write blob ae30c45e5269e678d7680af4eb997df7044f9a06: Invalid (offset, length) pair: [78333051]
# Failed to write blob 06a7b6a0ea6788f1f537229ec62171c7c6737f7f: Invalid (offset, length) pair: [72937069]
# Failed to write blob 8b137891791fe96927ad78e64b0aad7bded08bdc: Invalid (offset, length) pair: [7087416]
# Failed to write blob 373d14de1d42155621a8a0a27e116edc8a54818c: Invalid (offset, length) pair: [78343141]
# Failed to write blob ae0647dbbce892e9ec4afe6d86f11054b6dcb4c2: Invalid (offset, length) pair: [78333060]
# Failed to write blob b4a554dcd189d6605bbd5c0f53adf3121fe27cca: Invalid (offset, length) pair: [78336518]
# Failed to write blob 9cfa606967897fbe2c8eac25dd68b164e8d7aa9a: Invalid (offset, length) pair: [78362883]
# Failed to write blob c8d6af8e0f237eb5ea8270fd31b00a0b5b9f9e0c: Invalid (offset, length) pair: [72940860]
# Failed to write blob 5df3bd03fd108ecc75c7ff1e7b24897b35a4f858: Invalid (offset, length) pair: [72943714]
# Failed to write blob c29be2a7ca37ea8fcc0f89691309917b3a152059: Invalid (offset, length) pair: [72931077]
# Failed to write blob 8254140adf9b2c2462ff966895db5d1ac1b19a9f: Invalid (offset, length) pair: [17703128]
# Failed to write blob 8d1d72e55780ba47843bbd4dd81527c68a409b63: Invalid (offset, length) pair: [72970118]
# Failed to write blob d990e0d364f576ee83cd699707076ca49ad36a4d: Invalid (offset, length) pair: [61671254]
# Failed to write blob ed85e91a9766053840b2ca3a2869e33bbd06c194: Invalid (offset, length) pair: [72923251]
# Failed to write blob 47c4b07e24d6101b38bd7b08e6ef7451c4cb745d: Invalid (offset, length) pair: [72944206]
# Failed to write blob 975b9e13d25181b7863d025d33f928c87c310a27: Invalid (offset, length) pair: [72965217]
# Failed to write blob f7a13d3f0463abbdc6855c1c54997324b9580bc4: Invalid (offset, length) pair: [78342522]
# Failed to write blob a6f8be4464c5fa481a48d25de52500fea0e2e3c5: Invalid (offset, length) pair: [78355123]
# Failed to write blob cbcb46cc7d1f7342f9f55b65822d62deb17d9ccf: Invalid (offset, length) pair: [72962974]
# Failed to write blob 1b98588075fe018012921d6b152d7b82fd3afd95: Invalid (offset, length) pair: [78352638]
# Failed to write blob d990e0d364f576ee83cd699707076ca49ad36a4d: Invalid (offset, length) pair: [61671254]
# Failed to write blob f9ca05667a93c409c8d4869d9356f8bcd9160d22: Invalid (offset, length) pair: [75664064]
# Failed to write blob 0595cdf09a9c904f93eedbfbf735653694c41b14: Invalid (offset, length) pair: [72944269]
# Failed to write blob 842511621165fc2b2fd5cb03d204f02f1f985c31: Invalid (offset, length) pair: [72941038]
# Failed to write blob b4ae11e3b954f9b5adcd8948bdfb14c421f7e2ea: Invalid (offset, length) pair: [78336521]
# Failed to write blob 6f1184641b4cb26a37350fbae53ad530f0fea8b0: Invalid (offset, length) pair: [72907240]
# Failed to write blob d395c2c3e503f328de7a4964ff0f6b6b63f2d8f8: Invalid (offset, length) pair: [72950584]
# Failed to write blob 0cf146479d069bf0f657e5d611b17fc9b2d2586a: Invalid (offset, length) pair: [72967904]
# Failed to write blob caddbf84c56b1db7ced2bd665f5e87b38584abb9: Invalid (offset, length) pair: [72945753]
# Failed to write blob 9e93d0abf5b7554860c2d82eb3baeaa02ed2c193: Invalid (offset, length) pair: [78352594]
# Failed to write blob c8f906404a71f7ba138b54a8cb03b7b8b937a727: Invalid (offset, length) pair: [72940864]
# Failed to write blob d78ebca78e92a5680adb382c2939f70a2be1552b: Invalid (offset, length) pair: [72956083]
# Failed to write blob 3f78814edbc863ec24d4efdd36437186a66366ae: Invalid (offset, length) pair: [72938883]
# Failed to write blob beb53984333b5ec2f837e391e947382b54f39b8e: Invalid (offset, length) pair: [72961054]
# Failed to write blob 243b4f449c25b7c985d4ba8f6fb7d2a48e302c98: Invalid (offset, length) pair: [78344912]
# Failed to write blob 37d5db7c087f31a56d625bb2fceebd4c99d904bd: Invalid (offset, length) pair: [78343148]
# Failed to write blob cb990730c1987f2af2fc1463aa750937f606ba88: Invalid (offset, length) pair: [72962968]
# Failed to write blob 7b95c3635d7f9f591331e0decc9970c384ef9b18: Invalid (offset, length) pair: [75658172]
# Failed to write blob 1107d486c7d85fa888b309b673ef181975e991e8: Invalid (offset, length) pair: [72946092]
# Failed to write blob b4fe5c0fc77ea0fc25074ffe6f967e53ee294ba7: Invalid (offset, length) pair: [78336514]
# Failed to write blob 0a0de88c17dffc07b768fd70891063df0891fe55: Invalid (offset, length) pair: [72948095]
# Failed to write blob 00bc58014e8938dae35cca2bd1685a3081f1a132: Invalid (offset, length) pair: [72919623]
# Failed to write blob f6afdb958853c9f766997854f6580a05e0f48ecf: Invalid (offset, length) pair: [78323333]
# Failed to write blob 4973a05515a1ca47bb64795a71c23c0b24725069: Invalid (offset, length) pair: [72956966]
# Failed to write blob 51d7f31d29cab62f26feccb196e80b6e3efeb253: Invalid (offset, length) pair: [72944802]
# Failed to write blob c4dce762a8da3502bc3bb8384869c08705f09d60: Invalid (offset, length) pair: [72950315]
# Failed to write blob 2937387cbd241201f9d15dc78807a7891bf75275: Invalid (offset, length) pair: [78336500]
# Failed to write blob 00e7ad77958f70a9bbfe0767d36f568272bbd8d1: Invalid (offset, length) pair: [72919619]
# Failed to write blob 4179ea3e8f92da01e49982ecc2d4233aaccc686d: Invalid (offset, length) pair: [72933095]
# Failed to write blob 1102a338168113c9a287e09efaaab19ec327ef86: Invalid (offset, length) pair: [72946089]
# Failed to write blob b91042d8bad871c09d10a7d3c7835712d5421b75: Invalid (offset, length) pair: [78355458]
# Failed to write blob d5c75bd7d67795153a46028de11fec1b3688565e: Invalid (offset, length) pair: [72945381]
# Failed to write blob 71d154226f3d10e363f3860ab76e131a66e29e56: Invalid (offset, length) pair: [72932749]
# Failed to write blob d533cd2e82782aef578facc598b2d7740ab0b5b8: Invalid (offset, length) pair: [72945388]
# Failed to write blob 8856191680d59944b078dd1bb6ce4bf716da7a05: Invalid (offset, length) pair: [72943887]
# Failed to write blob 473cfb7777b5ecd8c941448d3041aa164841b90f: Invalid (offset, length) pair: [72944211]
# Failed to write blob ea4c6e34946b4594e86f766d31bfaba8869e8b04: Invalid (offset, length) pair: [72910417]
# Failed to write blob 0c2fceab99df105c19ff86562727358de90e423a: Invalid (offset, length) pair: [72967900]
# Failed to write blob 704ed07f5af7c743286d434010a060adb86fc644: Invalid (offset, length) pair: [72917449]
# Failed to write blob ac5cc0c9a8b3934f1296aac81db3a5a7fa4e11a5: Invalid (offset, length) pair: [78355769]
# Failed to write blob ab40b121c5cf7176f267100571eb129dc7e49a7c: Invalid (offset, length) pair: [78340506]
# Failed to write blob a6c4b657725d80c055b59d57bb4d338765ed4b11: Invalid (offset, length) pair: [78355124]
# Failed to write blob 6d1bfbffd3e03a37709e93c5794053ca00053f3b: Invalid (offset, length) pair: [72923255]
# Failed to write blob 20b3050904abc83c742275ad016ee5b5d2bdc390: Invalid (offset, length) pair: [78334310]
# Failed to write blob 8778f72a5f767ce8b4f7fd746482c1c4beeaf757: Invalid (offset, length) pair: [72956199]
# Failed to write blob 316edcf524f0f2896c665f2921cfbf9242236f1e: Invalid (offset, length) pair: [78340398]
# Failed to write blob 781d8d159e51f103005242839e7faeff031eafb7: Invalid (offset, length) pair: [75684112]
# Failed to write blob a9692ae498a075a8d0d9e68b87c433241457da1f: Invalid (offset, length) pair: [78336507]
# Failed to write blob 2529b6ce2a0b18e9d0bdadd8be4c039d6867d19d: Invalid (offset, length) pair: [78341928]
# Failed to write blob 63b06dfd5b414bda926de93dd99e318880c1c55a: Invalid (offset, length) pair: [72957940]
# Failed to write blob 3fcabffc94d79cdd57be86bc6723d57938aab337: Invalid (offset, length) pair: [72938886]
# Failed to write blob 3411ef2933dae0479483d21063091f276aba51df: Invalid (offset, length) pair: [78336513]
# Failed to write blob 12a9a1fdea841edb112eabbf8eee9fa47ccc29d2: Invalid (offset, length) pair: [72952149]
# Failed to write blob b817e3525db91a0fadb8fcd0300347e812fef2cb: Invalid (offset, length) pair: [78338075]
# Failed to write blob ee1f2ee39d15d5776fba4a6156c1f70f2b05d31d: Invalid (offset, length) pair: [72924953]
# Failed to write blob fcfe203e7e0ab25159cdfb1ebcab0e13286e4702: Invalid (offset, length) pair: [75658432]
# Failed to write blob de291dfaa942d621f85de012ffed82435459582a: Invalid (offset, length) pair: [72958242]
# Failed to write blob eefcc9adb33eca0c6ad1e9d2d6ff5c09c090a387: Invalid (offset, length) pair: [72924952]
# Failed to write blob a93f7b54a3b07e22b1015491a815c0c75c35b2df: Invalid (offset, length) pair: [78336504]
# Failed to write blob ba25cdef1032361f10488b0ad9e089d9eb7d7763: Invalid (offset, length) pair: [78363558]
# Failed to write blob d3223524e455555e202efc82e74783935bf0d544: Invalid (offset, length) pair: [72950595]
# Failed to write blob 6f310d64c83b92c4602aa82097bbcc4527e1fa82: Invalid (offset, length) pair: [72907241]
# Failed to write blob 9f490019ed04d12bde3e400b0320650d6a9196e4: Invalid (offset, length) pair: [78351242]
# Failed to write blob c7c28188accee2375c0790cc018c035ef23df9fd: Invalid (offset, length) pair: [72944216]
# Failed to write blob 63e5d83bcdb726c66a02014192d60f2e126082e1: Invalid (offset, length) pair: [72957941]
# Failed to write blob 694b98d67c3c51bb08f2dc4783dab6ad3fad3e88: Invalid (offset, length) pair: [72917149]
# Failed to write blob 2a223b3781b6f46496620fcff57020b97131b93b: Invalid (offset, length) pair: [78338656]
# Failed to write blob 4c275b047542398c42aa5f631310ca21eb0d8393: Invalid (offset, length) pair: [72950390]
# Failed to write blob 9ccb81ddac274ace04bd186d4e5f18078ce00a2c: Invalid (offset, length) pair: [78362879]
# Failed to write blob cce993718fb91a52adea9d816d8437d475ac14e3: Invalid (offset, length) pair: [72950387]
# Failed to write blob 5171f8e49f6513475690f86a31638b28bca4d459: Invalid (offset, length) pair: [72944799]
# Failed to write blob f2e917c722feb1d64c4e5cb52e6a5e173e896cc7: Invalid (offset, length) pair: [72922152]
# Failed to write blob d2f62551c2d50a0a8cdcb4fa017b0483a5e33da3: Invalid (offset, length) pair: [72935392]
# Failed to write blob 62fa741a673661662f5e6718eeefa3f9d322147e: Invalid (offset, length) pair: [72951430]
# Failed to write blob 7a1df769d8f083c99b30bf560f4fb115bb9bcefb: Invalid (offset, length) pair: [75681060]
# Failed to write blob 5f9e4788a08c7515ba3594e10201f97b2a0cba20: Invalid (offset, length) pair: [72938379]
# Failed to write blob ea05c70a7fbe6262dbf44d16ce79b9e76e0d0e71: Invalid (offset, length) pair: [72910415]
# Failed to write blob 0c644bde151e76e6a3701aafb33094346180fb61: Invalid (offset, length) pair: [72967894]
# Failed to write blob 5f1ff0d12ddad9a11b36d595fea1aa2a7971d022: Invalid (offset, length) pair: [72938385]
# Failed to write blob 12dc2f03d4fa25133d17bfb62b6d79d4fb211a7c: Invalid (offset, length) pair: [72952155]
# Failed to write blob a1bc506d1bbdb814ea7ae2bc51c770f198a42caa: Invalid (offset, length) pair: [78340128]
# Failed to write blob 27020e0248c95d1e5d0146b87428117d000befea: Invalid (offset, length) pair: [78349598]
# Failed to write blob 81f8eed832ecbb25d0303b7d5448263df76afdd5: Invalid (offset, length) pair: [72922474]
# Failed to write blob 5f101f2784a8c3705d40e5d4788f4c007ac093fb: Invalid (offset, length) pair: [72938378]
# Failed to write blob 4bbec57fb7e3d124d79fa25a1cb40cafef25cf64: Invalid (offset, length) pair: [72962967]
# Failed to write blob d98e02e1f4b2e82c6829a1ec6703c92a569d08e5: Invalid (offset, length) pair: [72953161]
# Failed to write blob aa1743881ecf9a0a6db8001be1d632cf364cf977: Invalid (offset, length) pair: [78338660]
# Failed to write blob b90e335b95be9a7ab45933cd0e3d119a86bca8d2: Invalid (offset, length) pair: [78355459]
# Failed to write blob 7e6f6855dd714e7f98a2279b106400c631cee8c5: Invalid (offset, length) pair: [75681095]
# Failed to write blob d3e8b383af61e72296ad0a906cc0137d603c2110: Invalid (offset, length) pair: [72950589]
# Failed to write blob f0aac96b8157ece90cf57a9689278ffbd4716183: Invalid (offset, length) pair: [72917455]
# Failed to write blob 502b228cd24e772f7b634406e191337bf37e123f: Invalid (offset, length) pair: [72955596]
# Failed to write blob 1c7a7ae49f058c91a79eb5e37d32ca84539a010d: Invalid (offset, length) pair: [92788617]
# Failed to write blob 4dbc330ea710d99385316a474e4199e94c335174: Invalid (offset, length) pair: [80948853]
# Failed to write blob 7e4eafb431583de7b1a15808f101747ac2f12491: Invalid (offset, length) pair: [75681097]
# Failed to write blob c434c4cc4f352e20e90a77fc2da23f578ca8eee7: Invalid (offset, length) pair: [72950308]
# Failed to write blob ca145ccecd541faa93f9b8efbc4733978e04f828: Invalid (offset, length) pair: [72945748]
# Failed to write blob e6c06b6a243774800b45e2110e2850775a386783: Invalid (offset, length) pair: [72937435]
# Failed to write blob 768e77aa821629a73b2539cbc982c2c7e0532878: Invalid (offset, length) pair: [78323343]
# Failed to write blob 7b87252491b78740cd17b7d180dfc10b27347e8e: Invalid (offset, length) pair: [75658180]
# Failed to write blob ab4c0237e3863f8728cfb03f9ad1b8e17c55f9d2: Invalid (offset, length) pair: [78340503]
# Failed to write blob 3c5bef237a8bad31f40bf7bd790ae99fca0a41b6: Invalid (offset, length) pair: [72937795]
# Failed to write blob 09d9deed3f4eca6b94b8a96a5eeff641dde7dcd2: Invalid (offset, length) pair: [72936083]
# Failed to write blob d690d1de191d68e078c0f65beecaf102bdcfd215: Invalid (offset, length) pair: [72957211]
# Failed to write blob f30a5cd04a0130779ae5005bf54d6e3fcb6d9699: Invalid (offset, length) pair: [72914012]
# Failed to write blob 6349accbc17e7e90f36532583173f736d11f5a04: Invalid (offset, length) pair: [72957947]
# Failed to write blob 0da04f7a4d5037c53915756e7f673f03be4deb8a: Invalid (offset, length) pair: [72970120]
# Failed to write blob 47f16ad9ed591f9ab06245b319fbb8cf6b2b2ee3: Invalid (offset, length) pair: [72944219]
# Failed to write blob d099fd693f463736696c4dcb669c48dc0bf49a27: Invalid (offset, length) pair: [72955599]
# Failed to write blob a02a858155480f2211f13fee4959b7998efabcb4: Invalid (offset, length) pair: [78334317]
# Failed to write blob 7fd10133be120e0aabeea980678b6cf115b8d5a4: Invalid (offset, length) pair: [75681742]
# Failed to write blob 4156ba6fe40dd02adcecb28664fa62d89b87228c: Invalid (offset, length) pair: [72933084]
# Failed to write blob ba41ee2bf21a99cb1064c40ab6bc08aa0d2178ce: Invalid (offset, length) pair: [78363560]
# Failed to write blob a436209f32c4138ec631235cb89b13bfa3c1f8b7: Invalid (offset, length) pair: [78344914]
# Failed to write blob 37019a5cdab533b6c7be6573e9f254cfe0f394f5: Invalid (offset, length) pair: [78343152]
# Failed to write blob d7cf5d25036aee1650d0da544bfec8315ace9e36: Invalid (offset, length) pair: [72956076]
# Failed to write blob bda967c46b4fc5ec958983778e81c902e1277045: Invalid (offset, length) pair: [72943457]
# Failed to write blob f4fdb086996e5aafb7b4906aded66ebdd4114385: Invalid (offset, length) pair: [78331844]
# Failed to write blob a31ab79f49a1f998309bcb5aba7a0d74b45f38cf: Invalid (offset, length) pair: [78336265]
# Failed to write blob f3ec3a797548b7f0963311eb7b16d50e5cecb554: Invalid (offset, length) pair: [72914015]
# Failed to write blob 33be3383bf72c0dbdbcbee521b20bd161053b2e0: Invalid (offset, length) pair: [78337770]
# Failed to write blob 5d01275df465a1f1d8dc71a7b4f1ddca13aac9ea: Invalid (offset, length) pair: [72943719]
# Failed to write blob f26f932496a11ab60b26147bf06ba94e6eb2255d: Invalid (offset, length) pair: [72922141]
# Failed to write blob 1b3aa00286a88cec774816dff58cc1890379fe65: Invalid (offset, length) pair: [78352628]
# Failed to write blob 265fe91efd9aa56f22ceef270f446faf2ea96599: Invalid (offset, length) pair: [78355122]
# Failed to write blob 866c1593bf48fdb15eb3fc6a20114253bfdd139e: Invalid (offset, length) pair: [72937071]
